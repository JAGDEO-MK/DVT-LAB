# %%
print("\nDataset Information:")
print(df.info())
print("\nSummary Statistics:")
print(df.describe())
print("\nMissing Values in Each Column:")
print(df.isnull().sum())

df = df.fillna(df.mean(numeric_only=True))

df = df.fillna("Unknown")

print("\nMissing Values After Handling:")
print(df.isnull().sum())
# Out:
# First 5 rows of the dataset:
#         post_id            timestamp day_of_week   platform        user_id  \
# 0  kcqbs6hxybia  2024-12-09 11:26:15      Monday  Instagram  user_52nwb0a6
# 1  vkmervg4ioos  2024-07-28 19:59:26      Sunday    Twitter  user_ucryct98
# 2  memhx4o1x6yu  2024-11-23 14:00:12    Saturday     Reddit  user_7rrev126
# 3  bhyo6piijqt9  2024-09-16 04:35:25      Monday    YouTube  user_4mxuq0ax
# 4  c9dkiomowakt  2024-09-05 21:03:01    Thursday    Twitter  user_l1vpox2k
#
#                location language  \
# 0  Melbourne, Australia       pt
# 1          Tokyo, Japan       ru
# 2        Beijing, China       ru
# 3        Lagos, Nigeria       en
# 4       Berlin, Germany       hi
#
#                                         text_content  \
# 0  Just tried the Chromebook from Google. Best pu...
# 1  Just saw an ad for Microsoft Surface Laptop du...
# 2  What's your opinion about Nike's Epic React?  ...
# 3  Bummed out with my new Diet Pepsi from Pepsi! ...
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HDC0422051\Desktop\dataset4DVT\Social Media Engagement Dataset.csv")
print("First 5 rows of the dataset:")
print(df.head())
df.to_csv(r"C:\Users\HDC0422051\Desktop\dataset4DVT\Social Media Engagement Dataset_Cleaned.csv", index=False)

print("\nCleaned dataset exported successfully!")
df.to_json(r"C:\Users\HDC0422051\Desktop\dataset4DVT\output.json", orient="records", indent=4)
df.to_excel(r"C:\Users\HDC0422051\Desktop\dataset4DVT\output.xlsx", index=False)
df.to_html(r"C:\Users\HDC0422051\Desktop\dataset4DVT\output.html", index=False)
# Out:
# First 5 rows of the dataset:
#         post_id            timestamp day_of_week   platform        user_id  \
# 0  kcqbs6hxybia  2024-12-09 11:26:15      Monday  Instagram  user_52nwb0a6
# 1  vkmervg4ioos  2024-07-28 19:59:26      Sunday    Twitter  user_ucryct98
# 2  memhx4o1x6yu  2024-11-23 14:00:12    Saturday     Reddit  user_7rrev126
# 3  bhyo6piijqt9  2024-09-16 04:35:25      Monday    YouTube  user_4mxuq0ax
# 4  c9dkiomowakt  2024-09-05 21:03:01    Thursday    Twitter  user_l1vpox2k
#
#                location language  \
# 0  Melbourne, Australia       pt
# 1          Tokyo, Japan       ru
# 2        Beijing, China       ru
# 3        Lagos, Nigeria       en
# 4       Berlin, Germany       hi
#
#                                         text_content  \
# 0  Just tried the Chromebook from Google. Best pu...
# 1  Just saw an ad for Microsoft Surface Laptop du...
# 2  What's your opinion about Nike's Epic React?  ...
# 3  Bummed out with my new Diet Pepsi from Pepsi! ...
# ...

# %%
import pandas as pd

df = pd.read_csv("Social Media Engagement Dataset.csv")
print(df.head())
# Out:
#         post_id            timestamp day_of_week   platform        user_id  \
# 0  kcqbs6hxybia  2024-12-09 11:26:15      Monday  Instagram  user_52nwb0a6
# 1  vkmervg4ioos  2024-07-28 19:59:26      Sunday    Twitter  user_ucryct98
# 2  memhx4o1x6yu  2024-11-23 14:00:12    Saturday     Reddit  user_7rrev126
# 3  bhyo6piijqt9  2024-09-16 04:35:25      Monday    YouTube  user_4mxuq0ax
# 4  c9dkiomowakt  2024-09-05 21:03:01    Thursday    Twitter  user_l1vpox2k
#
#                location language  \
# 0  Melbourne, Australia       pt
# 1          Tokyo, Japan       ru
# 2        Beijing, China       ru
# 3        Lagos, Nigeria       en
# 4       Berlin, Germany       hi
#
#                                         text_content  \
# 0  Just tried the Chromebook from Google. Best pu...
# 1  Just saw an ad for Microsoft Surface Laptop du...
# 2  What's your opinion about Nike's Epic React?  ...
# 3  Bummed out with my new Diet Pepsi from Pepsi! ...
# ...
